# %% [markdown]
# <a href="https://colab.research.google.com/github/data655/Data-Analysis-Portfolio/blob/main/Assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/blair-developer/dataMain/refs/heads/main/ecommerce_dataset_updated.csv')
df.head()
# Out:
#     User_ID  Product_ID  Category  Price (Rs.)  Discount (%)  \
# 0  337c166f  f414122f-e    Sports        36.53            15
# 1  d38a19bf  fde50f9c-5  Clothing       232.79            20
# 2  d7f5f0b0  0d96fc90-3    Sports       317.02            25
# 3  395d4994  964fc44b-d      Toys       173.19            25
# 4  a83c145c  d70e2fc6-e    Beauty       244.80            20
#
#    Final_Price(Rs.) Payment_Method Purchase_Date
# 0             31.05    Net Banking    12-11-2024
# 1            186.23    Net Banking    09-02-2024
# 2            237.76    Credit Card    01-09-2024
# 3            129.89            UPI    01-04-2024
# 4            195.84    Net Banking    27-09-2024

# %% [markdown]
# **Hypothesis Testing:**
#
# ---
#
#
#
# 1. Conduct a hypothesis test (Chi-Square Test) to check if there is a significant association between the product category (e.g., Sports, Clothing) and the payment method (e.g., Net Banking, Credit Card).

# %% [markdown]
# **Confidence Interval Calculation:**
#
# ---
#
#
# 2. Calculate the 95% confidence interval for the average final price (Final Price Rs.) of all purchases to estimate the range within which the true average final price lies.

# %% [markdown]
# **Correlation Coefficient Analysis:**
#
# ---
#
#
# 3. Determine the correlation coefficient to evaluate the linear relationship between original price (Price Rs.) and final price (Final Price Rs.) after applying discounts
